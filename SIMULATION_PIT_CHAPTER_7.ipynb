# %% [markdown]
# <a href="https://colab.research.google.com/github/jaraulahoneyj/Read/blob/main/SIMULATION_PIT_CHAPTER_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Chapter 7 - gradient_descent.py

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1,3,100)
y=x**2-2*x+1

fig = plt.figure()
axdef = fig.add_subplot(1, 1, 1)
axdef.spines['left'].set_position('center')
axdef.spines['bottom'].set_position('zero')
axdef.spines['right'].set_color('none')
axdef.spines['top'].set_color('none')
axdef.xaxis.set_ticks_position('bottom')
axdef.yaxis.set_ticks_position('left')

plt.plot(x,y, 'r')
plt.show()

#define the gradient function
Gradf = lambda x: 2*x-2

actual_X = 3
learning_rate = 0.01
precision_value = 0.000001
previous_step_size = 1
max_iteration = 10000
iteration_counter = 0

#iteration procedure
while previous_step_size > precision_value and \
iteration_counter < max_iteration :
    PreviousX = actual_X
    actual_X = actual_X - learning_rate * \
Gradf(PreviousX)
    previous_step_size = abs(actual_X - PreviousX)
    iteration_counter = iteration_counter +1
    print("Number of iterations = ",iteration_counter ,"\
nActual value of x is = ",actual_X )
    print("X value of f(x) minimum = ", actual_X )

print("X value of f(x) minimum = ", actual_X )
# Out:
# Number of iterations =  1 nActual value of x is =  2.96
# X value of f(x) minimum =  2.96
# Number of iterations =  2 nActual value of x is =  2.9208
# X value of f(x) minimum =  2.9208
# Number of iterations =  3 nActual value of x is =  2.882384
# X value of f(x) minimum =  2.882384
# Number of iterations =  4 nActual value of x is =  2.84473632
# X value of f(x) minimum =  2.84473632
# Number of iterations =  5 nActual value of x is =  2.8078415936
# X value of f(x) minimum =  2.8078415936
# Number of iterations =  6 nActual value of x is =  2.7716847617280003
# X value of f(x) minimum =  2.7716847617280003
# Number of iterations =  7 nActual value of x is =  2.7362510664934403
# X value of f(x) minimum =  2.7362510664934403
# Number of iterations =  8 nActual value of x is =  2.7015260451635714
# X value of f(x) minimum =  2.7015260451635714
# Number of iterations =  9 nActual value of x is =  2.6674955242603
# X value of f(x) minimum =  2.6674955242603
# Number of iterations =  10 nActual value of x is =  2.6341456137750936
# X value of f(x) minimum =  2.6341456137750936
# Number of iterations =  11 nActual value of x is =  2.601462701499592
# X value of f(x) minimum =  2.601462701499592
# Number of iterations =  12 nActual value of x is =  2.5694334474696
# X value of f(x) minimum =  2.5694334474696
# Number of iterations =  13 nActual value of x is =  2.538044778520208
# X value of f(x) minimum =  2.538044778520208
# Number of iterations =  14 nActual value of x is =  2.507283882949804
# X value of f(x) minimum =  2.507283882949804
# Number of iterations =  15 nActual value of x is =  2.477138205290808
# X value of f(x) minimum =  2.477138205290808
# Number of iterations =  16 nActual value of x is =  2.447595441184992
# X value of f(x) minimum =  2.447595441184992
# Number of iterations =  17 nActual value of x is =  2.418643532361292
# X value of f(x) minimum =  2.418643532361292
# Number of iterations =  18 nActual value of x is =  2.390270661714066
# X value of f(x) minimum =  2.390270661714066
# Number of iterations =  19 nActual value of x is =  2.3624652484797846
# X value of f(x) minimum =  2.3624652484797846
# Number of iterations =  20 nActual value of x is =  2.335215943510189
# X value of f(x) minimum =  2.335215943510189
# Number of iterations =  21 nActual value of x is =  2.3085116246399853
# X value of f(x) minimum =  2.3085116246399853
# Number of iterations =  22 nActual value of x is =  2.2823413921471856
# X value of f(x) minimum =  2.2823413921471856
# Number of iterations =  23 nActual value of x is =  2.256694564304242
# X value of f(x) minimum =  2.256694564304242
# Number of iterations =  24 nActual value of x is =  2.231560673018157
# X value of f(x) minimum =  2.231560673018157
# Number of iterations =  25 nActual value of x is =  2.206929459557794
# X value of f(x) minimum =  2.206929459557794
# Number of iterations =  26 nActual value of x is =  2.182790870366638
# X value of f(x) minimum =  2.182790870366638
# Number of iterations =  27 nActual value of x is =  2.1591350529593054
# X value of f(x) minimum =  2.1591350529593054
# Number of iterations =  28 nActual value of x is =  2.1359523519001193
# X value of f(x) minimum =  2.1359523519001193
# Number of iterations =  29 nActual value of x is =  2.113233304862117
# X value of f(x) minimum =  2.113233304862117
# Number of iterations =  30 nActual value of x is =  2.0909686387648745
# X value of f(x) minimum =  2.0909686387648745
# Number of iterations =  31 nActual value of x is =  2.069149265989577
# X value of f(x) minimum =  2.069149265989577
# Number of iterations =  32 nActual value of x is =  2.0477662806697854
# X value of f(x) minimum =  2.0477662806697854
# Number of iterations =  33 nActual value of x is =  2.0268109550563898
# X value of f(x) minimum =  2.0268109550563898
# Number of iterations =  34 nActual value of x is =  2.006274735955262
# X value of f(x) minimum =  2.006274735955262
# Number of iterations =  35 nActual value of x is =  1.9861492412361568
# X value of f(x) minimum =  1.9861492412361568
# Number of iterations =  36 nActual value of x is =  1.9664262564114336
# X value of f(x) minimum =  1.9664262564114336
# Number of iterations =  37 nActual value of x is =  1.947097731283205
# X value of f(x) minimum =  1.947097731283205
# Number of iterations =  38 nActual value of x is =  1.9281557766575408
# X value of f(x) minimum =  1.9281557766575408
# Number of iterations =  39 nActual value of x is =  1.90959266112439
# X value of f(x) minimum =  1.90959266112439
# Number of iterations =  40 nActual value of x is =  1.8914008079019022
# X value of f(x) minimum =  1.8914008079019022
# Number of iterations =  41 nActual value of x is =  1.8735727917438643
# X value of f(x) minimum =  1.8735727917438643
# Number of iterations =  42 nActual value of x is =  1.856101335908987
# X value of f(x) minimum =  1.856101335908987
# Number of iterations =  43 nActual value of x is =  1.8389793091908073
# X value of f(x) minimum =  1.8389793091908073
# Number of iterations =  44 nActual value of x is =  1.822199723006991
# X value of f(x) minimum =  1.822199723006991
# Number of iterations =  45 nActual value of x is =  1.8057557285468513
# X value of f(x) minimum =  1.8057557285468513
# Number of iterations =  46 nActual value of x is =  1.7896406139759142
# X value of f(x) minimum =  1.7896406139759142
# Number of iterations =  47 nActual value of x is =  1.7738478016963959
# X value of f(x) minimum =  1.7738478016963959
# Number of iterations =  48 nActual value of x is =  1.758370845662468
# X value of f(x) minimum =  1.758370845662468
# Number of iterations =  49 nActual value of x is =  1.7432034287492186
# X value of f(x) minimum =  1.7432034287492186
# Number of iterations =  50 nActual value of x is =  1.7283393601742343
# X value of f(x) minimum =  1.7283393601742343
# Number of iterations =  51 nActual value of x is =  1.7137725729707496
# X value of f(x) minimum =  1.7137725729707496
# Number of iterations =  52 nActual value of x is =  1.6994971215113346
# X value of f(x) minimum =  1.6994971215113346
# Number of iterations =  53 nActual value of x is =  1.6855071790811078
# X value of f(x) minimum =  1.6855071790811078
# Number of iterations =  54 nActual value of x is =  1.6717970354994856
# X value of f(x) minimum =  1.6717970354994856
# Number of iterations =  55 nActual value of x is =  1.6583610947894958
# X value of f(x) minimum =  1.6583610947894958
# Number of iterations =  56 nActual value of x is =  1.6451938728937059
# X value of f(x) minimum =  1.6451938728937059
# Number of iterations =  57 nActual value of x is =  1.6322899954358319
# X value of f(x) minimum =  1.6322899954358319
# Number of iterations =  58 nActual value of x is =  1.6196441955271152
# X value of f(x) minimum =  1.6196441955271152
# Number of iterations =  59 nActual value of x is =  1.607251311616573
# X value of f(x) minimum =  1.607251311616573
# Number of iterations =  60 nActual value of x is =  1.5951062853842415
# X value of f(x) minimum =  1.5951062853842415
# Number of iterations =  61 nActual value of x is =  1.5832041596765567
# X value of f(x) minimum =  1.5832041596765567
# Number of iterations =  62 nActual value of x is =  1.5715400764830256
# X value of f(x) minimum =  1.5715400764830256
# Number of iterations =  63 nActual value of x is =  1.5601092749533652
# X value of f(x) minimum =  1.5601092749533652
# Number of iterations =  64 nActual value of x is =  1.5489070894542978
# X value of f(x) minimum =  1.5489070894542978
# Number of iterations =  65 nActual value of x is =  1.5379289476652118
# X value of f(x) minimum =  1.5379289476652118
# Number of iterations =  66 nActual value of x is =  1.5271703687119076
# X value of f(x) minimum =  1.5271703687119076
# Number of iterations =  67 nActual value of x is =  1.5166269613376695
# X value of f(x) minimum =  1.5166269613376695
# Number of iterations =  68 nActual value of x is =  1.506294422110916
# X value of f(x) minimum =  1.506294422110916
# Number of iterations =  69 nActual value of x is =  1.4961685336686976
# X value of f(x) minimum =  1.4961685336686976
# Number of iterations =  70 nActual value of x is =  1.4862451629953237
# X value of f(x) minimum =  1.4862451629953237
# Number of iterations =  71 nActual value of x is =  1.4765202597354172
# X value of f(x) minimum =  1.4765202597354172
# Number of iterations =  72 nActual value of x is =  1.466989854540709
# X value of f(x) minimum =  1.466989854540709
# Number of iterations =  73 nActual value of x is =  1.4576500574498947
# X value of f(x) minimum =  1.4576500574498947
# Number of iterations =  74 nActual value of x is =  1.4484970563008968
# X value of f(x) minimum =  1.4484970563008968
# Number of iterations =  75 nActual value of x is =  1.4395271151748787
# X value of f(x) minimum =  1.4395271151748787
# Number of iterations =  76 nActual value of x is =  1.4307365728713812
# X value of f(x) minimum =  1.4307365728713812
# Number of iterations =  77 nActual value of x is =  1.4221218414139536
# X value of f(x) minimum =  1.4221218414139536
# Number of iterations =  78 nActual value of x is =  1.4136794045856744
# X value of f(x) minimum =  1.4136794045856744
# Number of iterations =  79 nActual value of x is =  1.405405816493961
# X value of f(x) minimum =  1.405405816493961
# Number of iterations =  80 nActual value of x is =  1.3972977001640816
# X value of f(x) minimum =  1.3972977001640816
# Number of iterations =  81 nActual value of x is =  1.3893517461608
# X value of f(x) minimum =  1.3893517461608
# Number of iterations =  82 nActual value of x is =  1.381564711237584
# X value of f(x) minimum =  1.381564711237584
# Number of iterations =  83 nActual value of x is =  1.3739334170128323
# X value of f(x) minimum =  1.3739334170128323
# Number of iterations =  84 nActual value of x is =  1.3664547486725758
# X value of f(x) minimum =  1.3664547486725758
# Number of iterations =  85 nActual value of x is =  1.3591256536991243
# X value of f(x) minimum =  1.3591256536991243
# Number of iterations =  86 nActual value of x is =  1.3519431406251419
# X value of f(x) minimum =  1.3519431406251419
# Number of iterations =  87 nActual value of x is =  1.344904277812639
# X value of f(x) minimum =  1.344904277812639
# Number of iterations =  88 nActual value of x is =  1.3380061922563862
# X value of f(x) minimum =  1.3380061922563862
# Number of iterations =  89 nActual value of x is =  1.3312460684112584
# X value of f(x) minimum =  1.3312460684112584
# Number of iterations =  90 nActual value of x is =  1.3246211470430331
# X value of f(x) minimum =  1.3246211470430331
# Number of iterations =  91 nActual value of x is =  1.3181287241021724
# X value of f(x) minimum =  1.3181287241021724
# Number of iterations =  92 nActual value of x is =  1.311766149620129
# X value of f(x) minimum =  1.311766149620129
# Number of iterations =  93 nActual value of x is =  1.3055308266277263
# X value of f(x) minimum =  1.3055308266277263
# Number of iterations =  94 nActual value of x is =  1.2994202100951717
# X value of f(x) minimum =  1.2994202100951717
# Number of iterations =  95 nActual value of x is =  1.2934318058932683
# X value of f(x) minimum =  1.2934318058932683
# Number of iterations =  96 nActual value of x is =  1.287563169775403
# X value of f(x) minimum =  1.287563169775403
# Number of iterations =  97 nActual value of x is =  1.281811906379895
# X value of f(x) minimum =  1.281811906379895
# Number of iterations =  98 nActual value of x is =  1.2761756682522971
# X value of f(x) minimum =  1.2761756682522971
# Number of iterations =  99 nActual value of x is =  1.2706521548872511
# X value of f(x) minimum =  1.2706521548872511
# Number of iterations =  100 nActual value of x is =  1.265239111789506
# X value of f(x) minimum =  1.265239111789506
# Number of iterations =  101 nActual value of x is =  1.259934329553716
# X value of f(x) minimum =  1.259934329553716
# Number of iterations =  102 nActual value of x is =  1.2547356429626417
# X value of f(x) minimum =  1.2547356429626417
# Number of iterations =  103 nActual value of x is =  1.2496409301033888
# X value of f(x) minimum =  1.2496409301033888
# Number of iterations =  104 nActual value of x is =  1.244648111501321
# X value of f(x) minimum =  1.244648111501321
# Number of iterations =  105 nActual value of x is =  1.2397551492712946
# X value of f(x) minimum =  1.2397551492712946
# Number of iterations =  106 nActual value of x is =  1.2349600462858688
# X value of f(x) minimum =  1.2349600462858688
# Number of iterations =  107 nActual value of x is =  1.2302608453601513
# X value of f(x) minimum =  1.2302608453601513
# Number of iterations =  108 nActual value of x is =  1.2256556284529483
# X value of f(x) minimum =  1.2256556284529483
# Number of iterations =  109 nActual value of x is =  1.2211425158838893
# X value of f(x) minimum =  1.2211425158838893
# Number of iterations =  110 nActual value of x is =  1.2167196655662116
# X value of f(x) minimum =  1.2167196655662116
# Number of iterations =  111 nActual value of x is =  1.2123852722548873
# X value of f(x) minimum =  1.2123852722548873
# Number of iterations =  112 nActual value of x is =  1.2081375668097896
# X value of f(x) minimum =  1.2081375668097896
# Number of iterations =  113 nActual value of x is =  1.2039748154735939
# X value of f(x) minimum =  1.2039748154735939
# Number of iterations =  114 nActual value of x is =  1.199895319164122
# X value of f(x) minimum =  1.199895319164122
# Number of iterations =  115 nActual value of x is =  1.1958974127808395
# X value of f(x) minimum =  1.1958974127808395
# Number of iterations =  116 nActual value of x is =  1.1919794645252226
# X value of f(x) minimum =  1.1919794645252226
# Number of iterations =  117 nActual value of x is =  1.188139875234718
# X value of f(x) minimum =  1.188139875234718
# Number of iterations =  118 nActual value of x is =  1.1843770777300238
# X value of f(x) minimum =  1.1843770777300238
# Number of iterations =  119 nActual value of x is =  1.1806895361754233
# X value of f(x) minimum =  1.1806895361754233
# Number of iterations =  120 nActual value of x is =  1.1770757454519147
# X value of f(x) minimum =  1.1770757454519147
# Number of iterations =  121 nActual value of x is =  1.1735342305428764
# X value of f(x) minimum =  1.1735342305428764
# Number of iterations =  122 nActual value of x is =  1.170063545932019
# X value of f(x) minimum =  1.170063545932019
# Number of iterations =  123 nActual value of x is =  1.1666622750133786
# X value of f(x) minimum =  1.1666622750133786
# Number of iterations =  124 nActual value of x is =  1.1633290295131111
# X value of f(x) minimum =  1.1633290295131111
# Number of iterations =  125 nActual value of x is =  1.1600624489228488
# X value of f(x) minimum =  1.1600624489228488
# Number of iterations =  126 nActual value of x is =  1.1568611999443918
# X value of f(x) minimum =  1.1568611999443918
# Number of iterations =  127 nActual value of x is =  1.153723975945504
# X value of f(x) minimum =  1.153723975945504
# Number of iterations =  128 nActual value of x is =  1.1506494964265939
# X value of f(x) minimum =  1.1506494964265939
# Number of iterations =  129 nActual value of x is =  1.147636506498062
# X value of f(x) minimum =  1.147636506498062
# Number of iterations =  130 nActual value of x is =  1.1446837763681008
# X value of f(x) minimum =  1.1446837763681008
# Number of iterations =  131 nActual value of x is =  1.1417901008407387
# X value of f(x) minimum =  1.1417901008407387
# Number of iterations =  132 nActual value of x is =  1.1389542988239238
# X value of f(x) minimum =  1.1389542988239238
# Number of iterations =  133 nActual value of x is =  1.1361752128474454
# X value of f(x) minimum =  1.1361752128474454
# Number of iterations =  134 nActual value of x is =  1.1334517085904965
# X value of f(x) minimum =  1.1334517085904965
# Number of iterations =  135 nActual value of x is =  1.1307826744186866
# X value of f(x) minimum =  1.1307826744186866
# Number of iterations =  136 nActual value of x is =  1.128167020930313
# X value of f(x) minimum =  1.128167020930313
# Number of iterations =  137 nActual value of x is =  1.1256036805117067
# X value of f(x) minimum =  1.1256036805117067
# Number of iterations =  138 nActual value of x is =  1.1230916069014725
# X value of f(x) minimum =  1.1230916069014725
# Number of iterations =  139 nActual value of x is =  1.120629774763443
# X value of f(x) minimum =  1.120629774763443
# Number of iterations =  140 nActual value of x is =  1.118217179268174
# X value of f(x) minimum =  1.118217179268174
# Number of iterations =  141 nActual value of x is =  1.1158528356828106
# X value of f(x) minimum =  1.1158528356828106
# Number of iterations =  142 nActual value of x is =  1.1135357789691545
# X value of f(x) minimum =  1.1135357789691545
# Number of iterations =  143 nActual value of x is =  1.1112650633897714
# X value of f(x) minimum =  1.1112650633897714
# Number of iterations =  144 nActual value of x is =  1.1090397621219759
# X value of f(x) minimum =  1.1090397621219759
# Number of iterations =  145 nActual value of x is =  1.1068589668795363
# X value of f(x) minimum =  1.1068589668795363
# Number of iterations =  146 nActual value of x is =  1.1047217875419455
# X value of f(x) minimum =  1.1047217875419455
# Number of iterations =  147 nActual value of x is =  1.1026273517911065
# X value of f(x) minimum =  1.1026273517911065
# Number of iterations =  148 nActual value of x is =  1.1005748047552844
# X value of f(x) minimum =  1.1005748047552844
# Number of iterations =  149 nActual value of x is =  1.0985633086601787
# X value of f(x) minimum =  1.0985633086601787
# Number of iterations =  150 nActual value of x is =  1.096592042486975
# X value of f(x) minimum =  1.096592042486975
# Number of iterations =  151 nActual value of x is =  1.0946602016372355
# X value of f(x) minimum =  1.0946602016372355
# Number of iterations =  152 nActual value of x is =  1.092766997604491
# X value of f(x) minimum =  1.092766997604491
# Number of iterations =  153 nActual value of x is =  1.0909116576524012
# X value of f(x) minimum =  1.0909116576524012
# Number of iterations =  154 nActual value of x is =  1.089093424499353
# X value of f(x) minimum =  1.089093424499353
# Number of iterations =  155 nActual value of x is =  1.087311556009366
# X value of f(x) minimum =  1.087311556009366
# Number of iterations =  156 nActual value of x is =  1.0855653248891788
# X value of f(x) minimum =  1.0855653248891788
# Number of iterations =  157 nActual value of x is =  1.0838540183913952
# X value of f(x) minimum =  1.0838540183913952
# Number of iterations =  158 nActual value of x is =  1.0821769380235673
# X value of f(x) minimum =  1.0821769380235673
# Number of iterations =  159 nActual value of x is =  1.0805333992630959
# X value of f(x) minimum =  1.0805333992630959
# Number of iterations =  160 nActual value of x is =  1.078922731277834
# X value of f(x) minimum =  1.078922731277834
# Number of iterations =  161 nActual value of x is =  1.0773442766522774
# X value of f(x) minimum =  1.0773442766522774
# Number of iterations =  162 nActual value of x is =  1.0757973911192318
# X value of f(x) minimum =  1.0757973911192318
# Number of iterations =  163 nActual value of x is =  1.074281443296847
# X value of f(x) minimum =  1.074281443296847
# Number of iterations =  164 nActual value of x is =  1.0727958144309102
# X value of f(x) minimum =  1.0727958144309102
# Number of iterations =  165 nActual value of x is =  1.071339898142292
# X value of f(x) minimum =  1.071339898142292
# Number of iterations =  166 nActual value of x is =  1.0699131001794462
# X value of f(x) minimum =  1.0699131001794462
# Number of iterations =  167 nActual value of x is =  1.0685148381758574
# X value of f(x) minimum =  1.0685148381758574
# Number of iterations =  168 nActual value of x is =  1.0671445414123402
# X value of f(x) minimum =  1.0671445414123402
# Number of iterations =  169 nActual value of x is =  1.0658016505840933
# X value of f(x) minimum =  1.0658016505840933
# Number of iterations =  170 nActual value of x is =  1.0644856175724113
# X value of f(x) minimum =  1.0644856175724113
# Number of iterations =  171 nActual value of x is =  1.0631959052209632
# X value of f(x) minimum =  1.0631959052209632
# Number of iterations =  172 nActual value of x is =  1.061931987116544
# X value of f(x) minimum =  1.061931987116544
# Number of iterations =  173 nActual value of x is =  1.060693347374213
# X value of f(x) minimum =  1.060693347374213
# Number of iterations =  174 nActual value of x is =  1.059479480426729
# X value of f(x) minimum =  1.059479480426729
# Number of iterations =  175 nActual value of x is =  1.0582898908181944
# X value of f(x) minimum =  1.0582898908181944
# Number of iterations =  176 nActual value of x is =  1.0571240930018304
# X value of f(x) minimum =  1.0571240930018304
# Number of iterations =  177 nActual value of x is =  1.055981611141794
# X value of f(x) minimum =  1.055981611141794
# Number of iterations =  178 nActual value of x is =  1.054861978918958
# X value of f(x) minimum =  1.054861978918958
# Number of iterations =  179 nActual value of x is =  1.0537647393405787
# X value of f(x) minimum =  1.0537647393405787
# Number of iterations =  180 nActual value of x is =  1.0526894445537671
# X value of f(x) minimum =  1.0526894445537671
# Number of iterations =  181 nActual value of x is =  1.0516356556626918
# X value of f(x) minimum =  1.0516356556626918
# Number of iterations =  182 nActual value of x is =  1.0506029425494379
# X value of f(x) minimum =  1.0506029425494379
# Number of iterations =  183 nActual value of x is =  1.049590883698449
# X value of f(x) minimum =  1.049590883698449
# Number of iterations =  184 nActual value of x is =  1.0485990660244802
# X value of f(x) minimum =  1.0485990660244802
# Number of iterations =  185 nActual value of x is =  1.0476270847039906
# X value of f(x) minimum =  1.0476270847039906
# Number of iterations =  186 nActual value of x is =  1.0466745430099107
# X value of f(x) minimum =  1.0466745430099107
# Number of iterations =  187 nActual value of x is =  1.0457410521497126
# X value of f(x) minimum =  1.0457410521497126
# Number of iterations =  188 nActual value of x is =  1.0448262311067182
# X value of f(x) minimum =  1.0448262311067182
# Number of iterations =  189 nActual value of x is =  1.0439297064845838
# X value of f(x) minimum =  1.0439297064845838
# Number of iterations =  190 nActual value of x is =  1.0430511123548922
# X value of f(x) minimum =  1.0430511123548922
# Number of iterations =  191 nActual value of x is =  1.0421900901077943
# X value of f(x) minimum =  1.0421900901077943
# Number of iterations =  192 nActual value of x is =  1.0413462883056384
# X value of f(x) minimum =  1.0413462883056384
# Number of iterations =  193 nActual value of x is =  1.0405193625395255
# X value of f(x) minimum =  1.0405193625395255
# Number of iterations =  194 nActual value of x is =  1.039708975288735
# X value of f(x) minimum =  1.039708975288735
# Number of iterations =  195 nActual value of x is =  1.0389147957829603
# X value of f(x) minimum =  1.0389147957829603
# Number of iterations =  196 nActual value of x is =  1.038136499867301
# X value of f(x) minimum =  1.038136499867301
# Number of iterations =  197 nActual value of x is =  1.037373769869955
# X value of f(x) minimum =  1.037373769869955
# Number of iterations =  198 nActual value of x is =  1.036626294472556
# X value of f(x) minimum =  1.036626294472556
# Number of iterations =  199 nActual value of x is =  1.035893768583105
# X value of f(x) minimum =  1.035893768583105
# Number of iterations =  200 nActual value of x is =  1.0351758932114428
# X value of f(x) minimum =  1.0351758932114428
# Number of iterations =  201 nActual value of x is =  1.0344723753472138
# X value of f(x) minimum =  1.0344723753472138
# Number of iterations =  202 nActual value of x is =  1.0337829278402695
# X value of f(x) minimum =  1.0337829278402695
# Number of iterations =  203 nActual value of x is =  1.0331072692834642
# X value of f(x) minimum =  1.0331072692834642
# Number of iterations =  204 nActual value of x is =  1.032445123897795
# X value of f(x) minimum =  1.032445123897795
# Number of iterations =  205 nActual value of x is =  1.031796221419839
# X value of f(x) minimum =  1.031796221419839
# Number of iterations =  206 nActual value of x is =  1.0311602969914422
# X value of f(x) minimum =  1.0311602969914422
# Number of iterations =  207 nActual value of x is =  1.0305370910516134
# X value of f(x) minimum =  1.0305370910516134
# Number of iterations =  208 nActual value of x is =  1.029926349230581
# X value of f(x) minimum =  1.029926349230581
# Number of iterations =  209 nActual value of x is =  1.0293278222459694
# X value of f(x) minimum =  1.0293278222459694
# Number of iterations =  210 nActual value of x is =  1.02874126580105
# X value of f(x) minimum =  1.02874126580105
# Number of iterations =  211 nActual value of x is =  1.028166440485029
# X value of f(x) minimum =  1.028166440485029
# Number of iterations =  212 nActual value of x is =  1.0276031116753284
# X value of f(x) minimum =  1.0276031116753284
# Number of iterations =  213 nActual value of x is =  1.027051049441822
# X value of f(x) minimum =  1.027051049441822
# Number of iterations =  214 nActual value of x is =  1.0265100284529856
# X value of f(x) minimum =  1.0265100284529856
# Number of iterations =  215 nActual value of x is =  1.0259798278839258
# X value of f(x) minimum =  1.0259798278839258
# Number of iterations =  216 nActual value of x is =  1.0254602313262473
# X value of f(x) minimum =  1.0254602313262473
# Number of iterations =  217 nActual value of x is =  1.0249510266997224
# X value of f(x) minimum =  1.0249510266997224
# Number of iterations =  218 nActual value of x is =  1.0244520061657278
# X value of f(x) minimum =  1.0244520061657278
# Number of iterations =  219 nActual value of x is =  1.0239629660424132
# X value of f(x) minimum =  1.0239629660424132
# Number of iterations =  220 nActual value of x is =  1.023483706721565
# X value of f(x) minimum =  1.023483706721565
# Number of iterations =  221 nActual value of x is =  1.0230140325871337
# X value of f(x) minimum =  1.0230140325871337
# Number of iterations =  222 nActual value of x is =  1.022553751935391
# X value of f(x) minimum =  1.022553751935391
# Number of iterations =  223 nActual value of x is =  1.0221026768966832
# X value of f(x) minimum =  1.0221026768966832
# Number of iterations =  224 nActual value of x is =  1.0216606233587495
# X value of f(x) minimum =  1.0216606233587495
# Number of iterations =  225 nActual value of x is =  1.0212274108915744
# X value of f(x) minimum =  1.0212274108915744
# Number of iterations =  226 nActual value of x is =  1.0208028626737429
# X value of f(x) minimum =  1.0208028626737429
# Number of iterations =  227 nActual value of x is =  1.020386805420268
# X value of f(x) minimum =  1.020386805420268
# Number of iterations =  228 nActual value of x is =  1.0199790693118627
# X value of f(x) minimum =  1.0199790693118627
# Number of iterations =  229 nActual value of x is =  1.0195794879256255
# X value of f(x) minimum =  1.0195794879256255
# Number of iterations =  230 nActual value of x is =  1.019187898167113
# X value of f(x) minimum =  1.019187898167113
# Number of iterations =  231 nActual value of x is =  1.0188041402037706
# X value of f(x) minimum =  1.0188041402037706
# Number of iterations =  232 nActual value of x is =  1.0184280573996953
# X value of f(x) minimum =  1.0184280573996953
# Number of iterations =  233 nActual value of x is =  1.0180594962517013
# X value of f(x) minimum =  1.0180594962517013
# Number of iterations =  234 nActual value of x is =  1.0176983063266674
# X value of f(x) minimum =  1.0176983063266674
# Number of iterations =  235 nActual value of x is =  1.017344340200134
# X value of f(x) minimum =  1.017344340200134
# Number of iterations =  236 nActual value of x is =  1.0169974533961315
# X value of f(x) minimum =  1.0169974533961315
# Number of iterations =  237 nActual value of x is =  1.016657504328209
# X value of f(x) minimum =  1.016657504328209
# Number of iterations =  238 nActual value of x is =  1.0163243542416447
# X value of f(x) minimum =  1.0163243542416447
# Number of iterations =  239 nActual value of x is =  1.0159978671568117
# X value of f(x) minimum =  1.0159978671568117
# Number of iterations =  240 nActual value of x is =  1.0156779098136755
# X value of f(x) minimum =  1.0156779098136755
# Number of iterations =  241 nActual value of x is =  1.015364351617402
# X value of f(x) minimum =  1.015364351617402
# Number of iterations =  242 nActual value of x is =  1.015057064585054
# X value of f(x) minimum =  1.015057064585054
# Number of iterations =  243 nActual value of x is =  1.014755923293353
# X value of f(x) minimum =  1.014755923293353
# Number of iterations =  244 nActual value of x is =  1.014460804827486
# X value of f(x) minimum =  1.014460804827486
# Number of iterations =  245 nActual value of x is =  1.0141715887309362
# X value of f(x) minimum =  1.0141715887309362
# Number of iterations =  246 nActual value of x is =  1.0138881569563174
# X value of f(x) minimum =  1.0138881569563174
# Number of iterations =  247 nActual value of x is =  1.013610393817191
# X value of f(x) minimum =  1.013610393817191
# Number of iterations =  248 nActual value of x is =  1.0133381859408472
# X value of f(x) minimum =  1.0133381859408472
# Number of iterations =  249 nActual value of x is =  1.0130714222220303
# X value of f(x) minimum =  1.0130714222220303
# Number of iterations =  250 nActual value of x is =  1.0128099937775896
# X value of f(x) minimum =  1.0128099937775896
# Number of iterations =  251 nActual value of x is =  1.012553793902038
# X value of f(x) minimum =  1.012553793902038
# Number of iterations =  252 nActual value of x is =  1.0123027180239972
# X value of f(x) minimum =  1.0123027180239972
# Number of iterations =  253 nActual value of x is =  1.0120566636635173
# X value of f(x) minimum =  1.0120566636635173
# Number of iterations =  254 nActual value of x is =  1.011815530390247
# X value of f(x) minimum =  1.011815530390247
# Number of iterations =  255 nActual value of x is =  1.011579219782442
# X value of f(x) minimum =  1.011579219782442
# Number of iterations =  256 nActual value of x is =  1.0113476353867932
# X value of f(x) minimum =  1.0113476353867932
# Number of iterations =  257 nActual value of x is =  1.0111206826790573
# X value of f(x) minimum =  1.0111206826790573
# Number of iterations =  258 nActual value of x is =  1.0108982690254762
# X value of f(x) minimum =  1.0108982690254762
# Number of iterations =  259 nActual value of x is =  1.0106803036449667
# X value of f(x) minimum =  1.0106803036449667
# Number of iterations =  260 nActual value of x is =  1.0104666975720673
# X value of f(x) minimum =  1.0104666975720673
# Number of iterations =  261 nActual value of x is =  1.010257363620626
# X value of f(x) minimum =  1.010257363620626
# Number of iterations =  262 nActual value of x is =  1.0100522163482135
# X value of f(x) minimum =  1.0100522163482135
# Number of iterations =  263 nActual value of x is =  1.0098511720212493
# X value of f(x) minimum =  1.0098511720212493
# Number of iterations =  264 nActual value of x is =  1.0096541485808244
# X value of f(x) minimum =  1.0096541485808244
# Number of iterations =  265 nActual value of x is =  1.0094610656092078
# X value of f(x) minimum =  1.0094610656092078
# Number of iterations =  266 nActual value of x is =  1.0092718442970237
# X value of f(x) minimum =  1.0092718442970237
# Number of iterations =  267 nActual value of x is =  1.0090864074110832
# X value of f(x) minimum =  1.0090864074110832
# Number of iterations =  268 nActual value of x is =  1.0089046792628615
# X value of f(x) minimum =  1.0089046792628615
# Number of iterations =  269 nActual value of x is =  1.0087265856776042
# X value of f(x) minimum =  1.0087265856776042
# Number of iterations =  270 nActual value of x is =  1.0085520539640522
# X value of f(x) minimum =  1.0085520539640522
# Number of iterations =  271 nActual value of x is =  1.0083810128847712
# X value of f(x) minimum =  1.0083810128847712
# Number of iterations =  272 nActual value of x is =  1.0082133926270758
# X value of f(x) minimum =  1.0082133926270758
# Number of iterations =  273 nActual value of x is =  1.0080491247745342
# X value of f(x) minimum =  1.0080491247745342
# Number of iterations =  274 nActual value of x is =  1.0078881422790436
# X value of f(x) minimum =  1.0078881422790436
# Number of iterations =  275 nActual value of x is =  1.0077303794334627
# X value of f(x) minimum =  1.0077303794334627
# Number of iterations =  276 nActual value of x is =  1.0075757718447935
# X value of f(x) minimum =  1.0075757718447935
# Number of iterations =  277 nActual value of x is =  1.0074242564078977
# X value of f(x) minimum =  1.0074242564078977
# Number of iterations =  278 nActual value of x is =  1.0072757712797398
# X value of f(x) minimum =  1.0072757712797398
# Number of iterations =  279 nActual value of x is =  1.007130255854145
# X value of f(x) minimum =  1.007130255854145
# Number of iterations =  280 nActual value of x is =  1.006987650737062
# X value of f(x) minimum =  1.006987650737062
# Number of iterations =  281 nActual value of x is =  1.0068478977223208
# X value of f(x) minimum =  1.0068478977223208
# Number of iterations =  282 nActual value of x is =  1.0067109397678744
# X value of f(x) minimum =  1.0067109397678744
# Number of iterations =  283 nActual value of x is =  1.006576720972517
# X value of f(x) minimum =  1.006576720972517
# Number of iterations =  284 nActual value of x is =  1.0064451865530666
# X value of f(x) minimum =  1.0064451865530666
# Number of iterations =  285 nActual value of x is =  1.0063162828220054
# X value of f(x) minimum =  1.0063162828220054
# Number of iterations =  286 nActual value of x is =  1.0061899571655653
# X value of f(x) minimum =  1.0061899571655653
# Number of iterations =  287 nActual value of x is =  1.0060661580222539
# X value of f(x) minimum =  1.0060661580222539
# Number of iterations =  288 nActual value of x is =  1.0059448348618087
# X value of f(x) minimum =  1.0059448348618087
# Number of iterations =  289 nActual value of x is =  1.0058259381645727
# X value of f(x) minimum =  1.0058259381645727
# Number of iterations =  290 nActual value of x is =  1.0057094194012812
# X value of f(x) minimum =  1.0057094194012812
# Number of iterations =  291 nActual value of x is =  1.0055952310132557
# X value of f(x) minimum =  1.0055952310132557
# Number of iterations =  292 nActual value of x is =  1.0054833263929905
# X value of f(x) minimum =  1.0054833263929905
# Number of iterations =  293 nActual value of x is =  1.0053736598651308
# X value of f(x) minimum =  1.0053736598651308
# Number of iterations =  294 nActual value of x is =  1.0052661866678283
# X value of f(x) minimum =  1.0052661866678283
# Number of iterations =  295 nActual value of x is =  1.0051608629344717
# X value of f(x) minimum =  1.0051608629344717
# Number of iterations =  296 nActual value of x is =  1.0050576456757823
# X value of f(x) minimum =  1.0050576456757823
# Number of iterations =  297 nActual value of x is =  1.0049564927622665
# X value of f(x) minimum =  1.0049564927622665
# Number of iterations =  298 nActual value of x is =  1.0048573629070212
# X value of f(x) minimum =  1.0048573629070212
# Number of iterations =  299 nActual value of x is =  1.0047602156488809
# X value of f(x) minimum =  1.0047602156488809
# Number of iterations =  300 nActual value of x is =  1.0046650113359032
# X value of f(x) minimum =  1.0046650113359032
# Number of iterations =  301 nActual value of x is =  1.0045717111091852
# X value of f(x) minimum =  1.0045717111091852
# Number of iterations =  302 nActual value of x is =  1.0044802768870016
# X value of f(x) minimum =  1.0044802768870016
# Number of iterations =  303 nActual value of x is =  1.0043906713492616
# X value of f(x) minimum =  1.0043906713492616
# Number of iterations =  304 nActual value of x is =  1.0043028579222764
# X value of f(x) minimum =  1.0043028579222764
# Number of iterations =  305 nActual value of x is =  1.0042168007638308
# X value of f(x) minimum =  1.0042168007638308
# Number of iterations =  306 nActual value of x is =  1.004132464748554
# X value of f(x) minimum =  1.004132464748554
# Number of iterations =  307 nActual value of x is =  1.004049815453583
# X value of f(x) minimum =  1.004049815453583
# Number of iterations =  308 nActual value of x is =  1.0039688191445113
# X value of f(x) minimum =  1.0039688191445113
# Number of iterations =  309 nActual value of x is =  1.0038894427616212
# X value of f(x) minimum =  1.0038894427616212
# Number of iterations =  310 nActual value of x is =  1.0038116539063888
# X value of f(x) minimum =  1.0038116539063888
# Number of iterations =  311 nActual value of x is =  1.003735420828261
# X value of f(x) minimum =  1.003735420828261
# Number of iterations =  312 nActual value of x is =  1.0036607124116956
# X value of f(x) minimum =  1.0036607124116956
# Number of iterations =  313 nActual value of x is =  1.0035874981634618
# X value of f(x) minimum =  1.0035874981634618
# Number of iterations =  314 nActual value of x is =  1.0035157482001926
# X value of f(x) minimum =  1.0035157482001926
# Number of iterations =  315 nActual value of x is =  1.0034454332361888
# X value of f(x) minimum =  1.0034454332361888
# Number of iterations =  316 nActual value of x is =  1.003376524571465
# X value of f(x) minimum =  1.003376524571465
# Number of iterations =  317 nActual value of x is =  1.0033089940800357
# X value of f(x) minimum =  1.0033089940800357
# Number of iterations =  318 nActual value of x is =  1.003242814198435
# X value of f(x) minimum =  1.003242814198435
# Number of iterations =  319 nActual value of x is =  1.0031779579144664
# X value of f(x) minimum =  1.0031779579144664
# Number of iterations =  320 nActual value of x is =  1.003114398756177
# X value of f(x) minimum =  1.003114398756177
# Number of iterations =  321 nActual value of x is =  1.0030521107810535
# X value of f(x) minimum =  1.0030521107810535
# Number of iterations =  322 nActual value of x is =  1.0029910685654324
# X value of f(x) minimum =  1.0029910685654324
# Number of iterations =  323 nActual value of x is =  1.0029312471941239
# X value of f(x) minimum =  1.0029312471941239
# Number of iterations =  324 nActual value of x is =  1.0028726222502413
# X value of f(x) minimum =  1.0028726222502413
# Number of iterations =  325 nActual value of x is =  1.0028151698052366
# X value of f(x) minimum =  1.0028151698052366
# Number of iterations =  326 nActual value of x is =  1.0027588664091318
# X value of f(x) minimum =  1.0027588664091318
# Number of iterations =  327 nActual value of x is =  1.002703689080949
# X value of f(x) minimum =  1.002703689080949
# Number of iterations =  328 nActual value of x is =  1.00264961529933
# X value of f(x) minimum =  1.00264961529933
# Number of iterations =  329 nActual value of x is =  1.0025966229933434
# X value of f(x) minimum =  1.0025966229933434
# Number of iterations =  330 nActual value of x is =  1.0025446905334765
# X value of f(x) minimum =  1.0025446905334765
# Number of iterations =  331 nActual value of x is =  1.002493796722807
# X value of f(x) minimum =  1.002493796722807
# Number of iterations =  332 nActual value of x is =  1.0024439207883509
# X value of f(x) minimum =  1.0024439207883509
# Number of iterations =  333 nActual value of x is =  1.0023950423725838
# X value of f(x) minimum =  1.0023950423725838
# Number of iterations =  334 nActual value of x is =  1.0023471415251322
# X value of f(x) minimum =  1.0023471415251322
# Number of iterations =  335 nActual value of x is =  1.0023001986946296
# X value of f(x) minimum =  1.0023001986946296
# Number of iterations =  336 nActual value of x is =  1.002254194720737
# X value of f(x) minimum =  1.002254194720737
# Number of iterations =  337 nActual value of x is =  1.0022091108263222
# X value of f(x) minimum =  1.0022091108263222
# Number of iterations =  338 nActual value of x is =  1.0021649286097958
# X value of f(x) minimum =  1.0021649286097958
# Number of iterations =  339 nActual value of x is =  1.0021216300376
# X value of f(x) minimum =  1.0021216300376
# Number of iterations =  340 nActual value of x is =  1.002079197436848
# X value of f(x) minimum =  1.002079197436848
# Number of iterations =  341 nActual value of x is =  1.002037613488111
# X value of f(x) minimum =  1.002037613488111
# Number of iterations =  342 nActual value of x is =  1.0019968612183487
# X value of f(x) minimum =  1.0019968612183487
# Number of iterations =  343 nActual value of x is =  1.0019569239939818
# X value of f(x) minimum =  1.0019569239939818
# Number of iterations =  344 nActual value of x is =  1.0019177855141022
# X value of f(x) minimum =  1.0019177855141022
# Number of iterations =  345 nActual value of x is =  1.00187942980382
# X value of f(x) minimum =  1.00187942980382
# Number of iterations =  346 nActual value of x is =  1.0018418412077437
# X value of f(x) minimum =  1.0018418412077437
# Number of iterations =  347 nActual value of x is =  1.0018050043835889
# X value of f(x) minimum =  1.0018050043835889
# Number of iterations =  348 nActual value of x is =  1.001768904295917
# X value of f(x) minimum =  1.001768904295917
# Number of iterations =  349 nActual value of x is =  1.0017335262099987
# X value of f(x) minimum =  1.0017335262099987
# Number of iterations =  350 nActual value of x is =  1.0016988556857986
# X value of f(x) minimum =  1.0016988556857986
# Number of iterations =  351 nActual value of x is =  1.0016648785720828
# X value of f(x) minimum =  1.0016648785720828
# Number of iterations =  352 nActual value of x is =  1.001631581000641
# X value of f(x) minimum =  1.001631581000641
# Number of iterations =  353 nActual value of x is =  1.0015989493806283
# X value of f(x) minimum =  1.0015989493806283
# Number of iterations =  354 nActual value of x is =  1.0015669703930157
# X value of f(x) minimum =  1.0015669703930157
# Number of iterations =  355 nActual value of x is =  1.0015356309851553
# X value of f(x) minimum =  1.0015356309851553
# Number of iterations =  356 nActual value of x is =  1.0015049183654523
# X value of f(x) minimum =  1.0015049183654523
# Number of iterations =  357 nActual value of x is =  1.0014748199981434
# X value of f(x) minimum =  1.0014748199981434
# Number of iterations =  358 nActual value of x is =  1.0014453235981804
# X value of f(x) minimum =  1.0014453235981804
# Number of iterations =  359 nActual value of x is =  1.0014164171262168
# X value of f(x) minimum =  1.0014164171262168
# Number of iterations =  360 nActual value of x is =  1.0013880887836923
# X value of f(x) minimum =  1.0013880887836923
# Number of iterations =  361 nActual value of x is =  1.0013603270080185
# X value of f(x) minimum =  1.0013603270080185
# Number of iterations =  362 nActual value of x is =  1.0013331204678582
# X value of f(x) minimum =  1.0013331204678582
# Number of iterations =  363 nActual value of x is =  1.001306458058501
# X value of f(x) minimum =  1.001306458058501
# Number of iterations =  364 nActual value of x is =  1.0012803288973309
# X value of f(x) minimum =  1.0012803288973309
# Number of iterations =  365 nActual value of x is =  1.0012547223193842
# X value of f(x) minimum =  1.0012547223193842
# Number of iterations =  366 nActual value of x is =  1.0012296278729964
# X value of f(x) minimum =  1.0012296278729964
# Number of iterations =  367 nActual value of x is =  1.0012050353155364
# X value of f(x) minimum =  1.0012050353155364
# Number of iterations =  368 nActual value of x is =  1.0011809346092257
# X value of f(x) minimum =  1.0011809346092257
# Number of iterations =  369 nActual value of x is =  1.0011573159170413
# X value of f(x) minimum =  1.0011573159170413
# Number of iterations =  370 nActual value of x is =  1.0011341695987004
# X value of f(x) minimum =  1.0011341695987004
# Number of iterations =  371 nActual value of x is =  1.0011114862067263
# X value of f(x) minimum =  1.0011114862067263
# Number of iterations =  372 nActual value of x is =  1.0010892564825917
# X value of f(x) minimum =  1.0010892564825917
# Number of iterations =  373 nActual value of x is =  1.00106747135294
# X value of f(x) minimum =  1.00106747135294
# Number of iterations =  374 nActual value of x is =  1.001046121925881
# X value of f(x) minimum =  1.001046121925881
# Number of iterations =  375 nActual value of x is =  1.0010251994873633
# X value of f(x) minimum =  1.0010251994873633
# Number of iterations =  376 nActual value of x is =  1.0010046954976162
# X value of f(x) minimum =  1.0010046954976162
# Number of iterations =  377 nActual value of x is =  1.0009846015876638
# X value of f(x) minimum =  1.0009846015876638
# Number of iterations =  378 nActual value of x is =  1.0009649095559106
# X value of f(x) minimum =  1.0009649095559106
# Number of iterations =  379 nActual value of x is =  1.0009456113647923
# X value of f(x) minimum =  1.0009456113647923
# Number of iterations =  380 nActual value of x is =  1.0009266991374965
# X value of f(x) minimum =  1.0009266991374965
# Number of iterations =  381 nActual value of x is =  1.0009081651547467
# X value of f(x) minimum =  1.0009081651547467
# Number of iterations =  382 nActual value of x is =  1.0008900018516518
# X value of f(x) minimum =  1.0008900018516518
# Number of iterations =  383 nActual value of x is =  1.0008722018146188
# X value of f(x) minimum =  1.0008722018146188
# Number of iterations =  384 nActual value of x is =  1.0008547577783264
# X value of f(x) minimum =  1.0008547577783264
# Number of iterations =  385 nActual value of x is =  1.00083766262276
# X value of f(x) minimum =  1.00083766262276
# Number of iterations =  386 nActual value of x is =  1.0008209093703049
# X value of f(x) minimum =  1.0008209093703049
# Number of iterations =  387 nActual value of x is =  1.0008044911828988
# X value of f(x) minimum =  1.0008044911828988
# Number of iterations =  388 nActual value of x is =  1.0007884013592407
# X value of f(x) minimum =  1.0007884013592407
# Number of iterations =  389 nActual value of x is =  1.000772633332056
# X value of f(x) minimum =  1.000772633332056
# Number of iterations =  390 nActual value of x is =  1.0007571806654147
# X value of f(x) minimum =  1.0007571806654147
# Number of iterations =  391 nActual value of x is =  1.0007420370521065
# X value of f(x) minimum =  1.0007420370521065
# Number of iterations =  392 nActual value of x is =  1.0007271963110644
# X value of f(x) minimum =  1.0007271963110644
# Number of iterations =  393 nActual value of x is =  1.000712652384843
# X value of f(x) minimum =  1.000712652384843
# Number of iterations =  394 nActual value of x is =  1.0006983993371463
# X value of f(x) minimum =  1.0006983993371463
# Number of iterations =  395 nActual value of x is =  1.0006844313504033
# X value of f(x) minimum =  1.0006844313504033
# Number of iterations =  396 nActual value of x is =  1.0006707427233952
# X value of f(x) minimum =  1.0006707427233952
# Number of iterations =  397 nActual value of x is =  1.0006573278689272
# X value of f(x) minimum =  1.0006573278689272
# Number of iterations =  398 nActual value of x is =  1.0006441813115488
# X value of f(x) minimum =  1.0006441813115488
# Number of iterations =  399 nActual value of x is =  1.0006312976853178
# X value of f(x) minimum =  1.0006312976853178
# Number of iterations =  400 nActual value of x is =  1.0006186717316115
# X value of f(x) minimum =  1.0006186717316115
# Number of iterations =  401 nActual value of x is =  1.0006062982969792
# X value of f(x) minimum =  1.0006062982969792
# Number of iterations =  402 nActual value of x is =  1.0005941723310396
# X value of f(x) minimum =  1.0005941723310396
# Number of iterations =  403 nActual value of x is =  1.000582288884419
# X value of f(x) minimum =  1.000582288884419
# Number of iterations =  404 nActual value of x is =  1.0005706431067305
# X value of f(x) minimum =  1.0005706431067305
# Number of iterations =  405 nActual value of x is =  1.0005592302445958
# X value of f(x) minimum =  1.0005592302445958
# Number of iterations =  406 nActual value of x is =  1.0005480456397038
# X value of f(x) minimum =  1.0005480456397038
# Number of iterations =  407 nActual value of x is =  1.0005370847269097
# X value of f(x) minimum =  1.0005370847269097
# Number of iterations =  408 nActual value of x is =  1.0005263430323714
# X value of f(x) minimum =  1.0005263430323714
# Number of iterations =  409 nActual value of x is =  1.000515816171724
# X value of f(x) minimum =  1.000515816171724
# Number of iterations =  410 nActual value of x is =  1.0005054998482896
# X value of f(x) minimum =  1.0005054998482896
# Number of iterations =  411 nActual value of x is =  1.0004953898513238
# X value of f(x) minimum =  1.0004953898513238
# Number of iterations =  412 nActual value of x is =  1.0004854820542972
# X value of f(x) minimum =  1.0004854820542972
# Number of iterations =  413 nActual value of x is =  1.0004757724132112
# X value of f(x) minimum =  1.0004757724132112
# Number of iterations =  414 nActual value of x is =  1.000466256964947
# X value of f(x) minimum =  1.000466256964947
# Number of iterations =  415 nActual value of x is =  1.000456931825648
# X value of f(x) minimum =  1.000456931825648
# Number of iterations =  416 nActual value of x is =  1.0004477931891351
# X value of f(x) minimum =  1.0004477931891351
# Number of iterations =  417 nActual value of x is =  1.0004388373253523
# X value of f(x) minimum =  1.0004388373253523
# Number of iterations =  418 nActual value of x is =  1.0004300605788452
# X value of f(x) minimum =  1.0004300605788452
# Number of iterations =  419 nActual value of x is =  1.0004214593672682
# X value of f(x) minimum =  1.0004214593672682
# Number of iterations =  420 nActual value of x is =  1.0004130301799228
# X value of f(x) minimum =  1.0004130301799228
# Number of iterations =  421 nActual value of x is =  1.0004047695763243
# X value of f(x) minimum =  1.0004047695763243
# Number of iterations =  422 nActual value of x is =  1.0003966741847978
# X value of f(x) minimum =  1.0003966741847978
# Number of iterations =  423 nActual value of x is =  1.0003887407011018
# X value of f(x) minimum =  1.0003887407011018
# Number of iterations =  424 nActual value of x is =  1.0003809658870797
# X value of f(x) minimum =  1.0003809658870797
# Number of iterations =  425 nActual value of x is =  1.000373346569338
# X value of f(x) minimum =  1.000373346569338
# Number of iterations =  426 nActual value of x is =  1.0003658796379513
# X value of f(x) minimum =  1.0003658796379513
# Number of iterations =  427 nActual value of x is =  1.0003585620451922
# X value of f(x) minimum =  1.0003585620451922
# Number of iterations =  428 nActual value of x is =  1.0003513908042885
# X value of f(x) minimum =  1.0003513908042885
# Number of iterations =  429 nActual value of x is =  1.0003443629882027
# X value of f(x) minimum =  1.0003443629882027
# Number of iterations =  430 nActual value of x is =  1.0003374757284387
# X value of f(x) minimum =  1.0003374757284387
# Number of iterations =  431 nActual value of x is =  1.0003307262138699
# X value of f(x) minimum =  1.0003307262138699
# Number of iterations =  432 nActual value of x is =  1.0003241116895925
# X value of f(x) minimum =  1.0003241116895925
# Number of iterations =  433 nActual value of x is =  1.0003176294558007
# X value of f(x) minimum =  1.0003176294558007
# Number of iterations =  434 nActual value of x is =  1.0003112768666846
# X value of f(x) minimum =  1.0003112768666846
# Number of iterations =  435 nActual value of x is =  1.000305051329351
# X value of f(x) minimum =  1.000305051329351
# Number of iterations =  436 nActual value of x is =  1.000298950302764
# X value of f(x) minimum =  1.000298950302764
# Number of iterations =  437 nActual value of x is =  1.0002929712967086
# X value of f(x) minimum =  1.0002929712967086
# Number of iterations =  438 nActual value of x is =  1.0002871118707743
# X value of f(x) minimum =  1.0002871118707743
# Number of iterations =  439 nActual value of x is =  1.0002813696333588
# X value of f(x) minimum =  1.0002813696333588
# Number of iterations =  440 nActual value of x is =  1.0002757422406916
# X value of f(x) minimum =  1.0002757422406916
# Number of iterations =  441 nActual value of x is =  1.0002702273958777
# X value of f(x) minimum =  1.0002702273958777
# Number of iterations =  442 nActual value of x is =  1.00026482284796
# X value of f(x) minimum =  1.00026482284796
# Number of iterations =  443 nActual value of x is =  1.0002595263910008
# X value of f(x) minimum =  1.0002595263910008
# Number of iterations =  444 nActual value of x is =  1.0002543358631808
# X value of f(x) minimum =  1.0002543358631808
# Number of iterations =  445 nActual value of x is =  1.0002492491459172
# X value of f(x) minimum =  1.0002492491459172
# Number of iterations =  446 nActual value of x is =  1.000244264162999
# X value of f(x) minimum =  1.000244264162999
# Number of iterations =  447 nActual value of x is =  1.000239378879739
# X value of f(x) minimum =  1.000239378879739
# Number of iterations =  448 nActual value of x is =  1.0002345913021442
# X value of f(x) minimum =  1.0002345913021442
# Number of iterations =  449 nActual value of x is =  1.0002298994761014
# X value of f(x) minimum =  1.0002298994761014
# Number of iterations =  450 nActual value of x is =  1.0002253014865794
# X value of f(x) minimum =  1.0002253014865794
# Number of iterations =  451 nActual value of x is =  1.0002207954568478
# X value of f(x) minimum =  1.0002207954568478
# Number of iterations =  452 nActual value of x is =  1.0002163795477108
# X value of f(x) minimum =  1.0002163795477108
# Number of iterations =  453 nActual value of x is =  1.0002120519567566
# X value of f(x) minimum =  1.0002120519567566
# Number of iterations =  454 nActual value of x is =  1.0002078109176213
# X value of f(x) minimum =  1.0002078109176213
# Number of iterations =  455 nActual value of x is =  1.000203654699269
# X value of f(x) minimum =  1.000203654699269
# Number of iterations =  456 nActual value of x is =  1.0001995816052835
# X value of f(x) minimum =  1.0001995816052835
# Number of iterations =  457 nActual value of x is =  1.0001955899731778
# X value of f(x) minimum =  1.0001955899731778
# Number of iterations =  458 nActual value of x is =  1.0001916781737143
# X value of f(x) minimum =  1.0001916781737143
# Number of iterations =  459 nActual value of x is =  1.0001878446102401
# X value of f(x) minimum =  1.0001878446102401
# Number of iterations =  460 nActual value of x is =  1.0001840877180352
# X value of f(x) minimum =  1.0001840877180352
# Number of iterations =  461 nActual value of x is =  1.0001804059636745
# X value of f(x) minimum =  1.0001804059636745
# Number of iterations =  462 nActual value of x is =  1.000176797844401
# X value of f(x) minimum =  1.000176797844401
# Number of iterations =  463 nActual value of x is =  1.000173261887513
# X value of f(x) minimum =  1.000173261887513
# Number of iterations =  464 nActual value of x is =  1.0001697966497627
# X value of f(x) minimum =  1.0001697966497627
# Number of iterations =  465 nActual value of x is =  1.0001664007167674
# X value of f(x) minimum =  1.0001664007167674
# Number of iterations =  466 nActual value of x is =  1.000163072702432
# X value of f(x) minimum =  1.000163072702432
# Number of iterations =  467 nActual value of x is =  1.0001598112483834
# X value of f(x) minimum =  1.0001598112483834
# Number of iterations =  468 nActual value of x is =  1.0001566150234158
# X value of f(x) minimum =  1.0001566150234158
# Number of iterations =  469 nActual value of x is =  1.0001534827229475
# X value of f(x) minimum =  1.0001534827229475
# Number of iterations =  470 nActual value of x is =  1.0001504130684886
# X value of f(x) minimum =  1.0001504130684886
# Number of iterations =  471 nActual value of x is =  1.0001474048071188
# X value of f(x) minimum =  1.0001474048071188
# Number of iterations =  472 nActual value of x is =  1.0001444567109765
# X value of f(x) minimum =  1.0001444567109765
# Number of iterations =  473 nActual value of x is =  1.0001415675767569
# X value of f(x) minimum =  1.0001415675767569
# Number of iterations =  474 nActual value of x is =  1.0001387362252216
# X value of f(x) minimum =  1.0001387362252216
# Number of iterations =  475 nActual value of x is =  1.0001359615007173
# X value of f(x) minimum =  1.0001359615007173
# Number of iterations =  476 nActual value of x is =  1.000133242270703
# X value of f(x) minimum =  1.000133242270703
# Number of iterations =  477 nActual value of x is =  1.0001305774252889
# X value of f(x) minimum =  1.0001305774252889
# Number of iterations =  478 nActual value of x is =  1.0001279658767832
# X value of f(x) minimum =  1.0001279658767832
# Number of iterations =  479 nActual value of x is =  1.0001254065592475
# X value of f(x) minimum =  1.0001254065592475
# Number of iterations =  480 nActual value of x is =  1.0001228984280626
# X value of f(x) minimum =  1.0001228984280626
# Number of iterations =  481 nActual value of x is =  1.0001204404595012
# X value of f(x) minimum =  1.0001204404595012
# Number of iterations =  482 nActual value of x is =  1.000118031650311
# X value of f(x) minimum =  1.000118031650311
# Number of iterations =  483 nActual value of x is =  1.000115671017305
# X value of f(x) minimum =  1.000115671017305
# Number of iterations =  484 nActual value of x is =  1.0001133575969587
# X value of f(x) minimum =  1.0001133575969587
# Number of iterations =  485 nActual value of x is =  1.0001110904450197
# X value of f(x) minimum =  1.0001110904450197
# Number of iterations =  486 nActual value of x is =  1.0001088686361193
# X value of f(x) minimum =  1.0001088686361193
# Number of iterations =  487 nActual value of x is =  1.000106691263397
# X value of f(x) minimum =  1.000106691263397
# Number of iterations =  488 nActual value of x is =  1.0001045574381289
# X value of f(x) minimum =  1.0001045574381289
# Number of iterations =  489 nActual value of x is =  1.0001024662893663
# X value of f(x) minimum =  1.0001024662893663
# Number of iterations =  490 nActual value of x is =  1.000100416963579
# X value of f(x) minimum =  1.000100416963579
# Number of iterations =  491 nActual value of x is =  1.0000984086243074
# X value of f(x) minimum =  1.0000984086243074
# Number of iterations =  492 nActual value of x is =  1.0000964404518213
# X value of f(x) minimum =  1.0000964404518213
# Number of iterations =  493 nActual value of x is =  1.0000945116427848
# X value of f(x) minimum =  1.0000945116427848
# Number of iterations =  494 nActual value of x is =  1.000092621409929
# X value of f(x) minimum =  1.000092621409929
# Number of iterations =  495 nActual value of x is =  1.0000907689817304
# X value of f(x) minimum =  1.0000907689817304
# Number of iterations =  496 nActual value of x is =  1.0000889536020958
# X value of f(x) minimum =  1.0000889536020958
# Number of iterations =  497 nActual value of x is =  1.000087174530054
# X value of f(x) minimum =  1.000087174530054
# Number of iterations =  498 nActual value of x is =  1.000085431039453
# X value of f(x) minimum =  1.000085431039453
# Number of iterations =  499 nActual value of x is =  1.0000837224186638
# X value of f(x) minimum =  1.0000837224186638
# Number of iterations =  500 nActual value of x is =  1.0000820479702905
# X value of f(x) minimum =  1.0000820479702905
# Number of iterations =  501 nActual value of x is =  1.0000804070108846
# X value of f(x) minimum =  1.0000804070108846
# Number of iterations =  502 nActual value of x is =  1.000078798870667
# X value of f(x) minimum =  1.000078798870667
# Number of iterations =  503 nActual value of x is =  1.0000772228932537
# X value of f(x) minimum =  1.0000772228932537
# Number of iterations =  504 nActual value of x is =  1.0000756784353886
# X value of f(x) minimum =  1.0000756784353886
# Number of iterations =  505 nActual value of x is =  1.0000741648666809
# X value of f(x) minimum =  1.0000741648666809
# Number of iterations =  506 nActual value of x is =  1.0000726815693473
# X value of f(x) minimum =  1.0000726815693473
# Number of iterations =  507 nActual value of x is =  1.0000712279379602
# X value of f(x) minimum =  1.0000712279379602
# Number of iterations =  508 nActual value of x is =  1.000069803379201
# X value of f(x) minimum =  1.000069803379201
# Number of iterations =  509 nActual value of x is =  1.000068407311617
# X value of f(x) minimum =  1.000068407311617
# Number of iterations =  510 nActual value of x is =  1.0000670391653848
# X value of f(x) minimum =  1.0000670391653848
# Number of iterations =  511 nActual value of x is =  1.000065698382077
# X value of f(x) minimum =  1.000065698382077
# Number of iterations =  512 nActual value of x is =  1.0000643844144355
# X value of f(x) minimum =  1.0000643844144355
# Number of iterations =  513 nActual value of x is =  1.0000630967261468
# X value of f(x) minimum =  1.0000630967261468
# Number of iterations =  514 nActual value of x is =  1.000061834791624
# X value of f(x) minimum =  1.000061834791624
# Number of iterations =  515 nActual value of x is =  1.0000605980957915
# X value of f(x) minimum =  1.0000605980957915
# Number of iterations =  516 nActual value of x is =  1.0000593861338756
# X value of f(x) minimum =  1.0000593861338756
# Number of iterations =  517 nActual value of x is =  1.000058198411198
# X value of f(x) minimum =  1.000058198411198
# Number of iterations =  518 nActual value of x is =  1.000057034442974
# X value of f(x) minimum =  1.000057034442974
# Number of iterations =  519 nActual value of x is =  1.0000558937541144
# X value of f(x) minimum =  1.0000558937541144
# Number of iterations =  520 nActual value of x is =  1.0000547758790321
# X value of f(x) minimum =  1.0000547758790321
# Number of iterations =  521 nActual value of x is =  1.0000536803614515
# X value of f(x) minimum =  1.0000536803614515
# Number of iterations =  522 nActual value of x is =  1.0000526067542224
# X value of f(x) minimum =  1.0000526067542224
# Number of iterations =  523 nActual value of x is =  1.000051554619138
# X value of f(x) minimum =  1.000051554619138
# Number of iterations =  524 nActual value of x is =  1.0000505235267552
# X value of f(x) minimum =  1.0000505235267552
# Number of iterations =  525 nActual value of x is =  1.0000495130562201
# X value of f(x) minimum =  1.0000495130562201
# Number of iterations =  526 nActual value of x is =  1.0000485227950957
# X value of f(x) minimum =  1.0000485227950957
# X value of f(x) minimum =  1.0000485227950957

# %% [markdown]
# Chapter 7 - newton_raphson.py

# %%
import numpy as np
import matplotlib.pyplot as plt

#define the function
x = np.linspace(0,3,100)
y=x**3 -2*x**2 -x + 2

fig = plt.figure()
axdef = fig.add_subplot(1, 1, 1)
axdef.spines['left'].set_position('center')
axdef.spines['bottom'].set_position('zero')
axdef.spines['right'].set_color('none')
axdef.spines['top'].set_color('none')
axdef.xaxis.set_ticks_position('bottom')
axdef.yaxis.set_ticks_position('left')
plt.plot(x,y, 'r')
plt.show()

print('Value of x at the minimum of the function', x[np.
argmin(y)])

#define the first and second derivative functions
FirstDerivative = lambda x: 3*x**2-4*x -1
SecondDerivative = lambda x: 6*x-4

actual_X = 3
precision_value = 0.000001
previous_step_size = 1
max_iteration = 10000
iteration_counter = 0

#we can now apply Newton-Raphson method
while previous_step_size > precision_value and iteration_counter < max_iteration :
    PreviousX = actual_X
    actual_X = actual_X - FirstDerivative(PreviousX)/ SecondDerivative(PreviousX)
    previous_step_size = abs(actual_X - PreviousX)
    iteration_counter = iteration_counter +1
    print("Number of iterations = ",iteration_counter ,"\
nActual value of x is = ",actual_X )

print("X value of f(x) minimum = ", actual_X )
# Out:
# Value of x at the minimum of the function 1.5454545454545454
# Number of iterations =  1 nActual value of x is =  2.0
# Number of iterations =  2 nActual value of x is =  1.625
# Number of iterations =  3 nActual value of x is =  1.5516304347826086
# Number of iterations =  4 nActual value of x is =  1.5485890147300967
# Number of iterations =  5 nActual value of x is =  1.5485837703704566
# Number of iterations =  6 nActual value of x is =  1.5485837703548635
# X value of f(x) minimum =  1.5485837703548635

# %% [markdown]
# Chapter 7 - gaussian_mixtures.py

# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.mixture import GaussianMixture
import pandas as pd

mean_1=25
st_1=9
mean_2=50
st_2=5

n_dist_1 = np.random.normal(loc=mean_1, scale=st_1, size=3000)
n_dist_2 = np.random.normal(loc=mean_2, scale=st_2, size=7000)

dist_merged = np.hstack((n_dist_1, n_dist_2))

sns.set_style("white")
sns.histplot(data=dist_merged, kde=True)
plt.show()

dist_merged_res = dist_merged.reshape((len(dist_merged), 1))
gm_model = GaussianMixture(n_components=2, init_params='kmeans')
gm_model.fit(dist_merged_res)

print(f"Initial distribution means = {mean_1,mean_2}")
print(f"Initial distribution standard deviation = {st_1,st_2}")

print(f"GM_model distribution means = {gm_model.means_}")
print(f"GM_model distribution standard deviation = {np.sqrt(gm_model.covariances_)}")

dist_labels = gm_model.predict(dist_merged_res)

sns.set_style("white")
data_pred=pd.DataFrame({'data':dist_merged, 'label':dist_labels})
sns.histplot(data = data_pred, x = "data", kde = True, hue = "label")
plt.show()

label_0 = np.zeros(3000, dtype=int)
label_1 = np.ones(7000, dtype=int)
labels_merged = np.hstack((label_0, label_1))
data_init=pd.DataFrame({'data':dist_merged, 'label':labels_merged})

sns.set_style("white")
sns.histplot(data = data_init, x = "data", kde = True, hue = "label")
plt.show()
# Out:
# Initial distribution means = (25, 50)
# Initial distribution standard deviation = (9, 5)
# GM_model distribution means = [[49.78877375]
#  [24.26475112]]
# GM_model distribution standard deviation = [[[5.14264405]]
#
#  [[8.333788  ]]]

# %% [markdown]
# Chapter 7 - simulated_annealing.py

# %%
import numpy as np
import matplotlib.pyplot as plt

x= np.linspace(0,10,1000)
def cost_function(x):
    return x*np.sin(2.1*x+1)

plt.plot(x,cost_function(x))
plt.xlabel('X')
plt.ylabel('Cost Function')
plt.show()

temp = 2000
iter = 2000
step_size = 0.1

np.random.seed(15)
xi = np.random.uniform(min(x), max(x))
E_xi = cost_function(xi)
xit, E_xit = xi, E_xi
cost_func_eval = []
acc_prob = 1

for i in range(iter):
      xstep = xit + np.random.randn() * step_size
      E_step = cost_function(xstep)

      if E_step < E_xi:
          xi, E_xi = xstep, E_step
          cost_func_eval.append(E_xi)
          print('Iteration = ',i,'x_min = ',xi,'Global Minimum =', E_xi, 'Acceptance Probability =', acc_prob)
      diff_energy = E_step - E_xit
      t = temp /(i + 1)
      acc_prob = np.exp(-diff_energy/ t)

      if (diff_energy < 0 or
              np.random.randn() < acc_prob):
              xit, E_xit = xstep, E_step

plt.plot(cost_func_eval, 'bs--')
plt.xlabel('Improvement Step')
plt.ylabel('Cost Function improvement')
plt.show()
# Out:
# Iteration =  0 x_min =  8.352060345432603 Global Minimum = -2.549691087509061 Acceptance Probability = 1
# Iteration =  1 x_min =  8.268146731695177 Global Minimum = -3.865265080181498 Acceptance Probability = 1.0011720530797679
# Iteration =  2 x_min =  8.077074224781931 Global Minimum = -6.264757086553908 Acceptance Probability = 1.0013164397397474
# Iteration =  4 x_min =  8.072960126990173 Global Minimum = -6.3053561226675905 Acceptance Probability = 0.9993874938212183
# Iteration =  14 x_min =  8.057426141282635 Global Minimum = -6.45398523520768 Acceptance Probability = 1.0011249991583007
# Iteration =  17 x_min =  7.908942504770391 Global Minimum = -7.482144101692382 Acceptance Probability = 0.9960707945643333
# Iteration =  18 x_min =  7.805571271239743 Global Minimum = -7.755842336539771 Acceptance Probability = 1.0092963751415767
# Iteration =  21 x_min =  7.767739570791674 Global Minimum = -7.763382995462104 Acceptance Probability = 1.0072493114830527
# Iteration =  27 x_min =  7.793961859355448 Global Minimum = -7.763418087146118 Acceptance Probability = 0.9975392161808777
# Iteration =  36 x_min =  7.775446728598834 Global Minimum = -7.765853968129766 Acceptance Probability = 1.007367947545534
# Iteration =  41 x_min =  7.778624797903834 Global Minimum = -7.766277157406623 Acceptance Probability = 0.9981491502724658
# Iteration =  138 x_min =  7.781197205345049 Global Minimum = -7.766364644616736 Acceptance Probability = 1.036566292077183
# Iteration =  1174 x_min =  7.78075358444397 Global Minimum = -7.7663658475723265 Acceptance Probability = 1.3178155041756248
